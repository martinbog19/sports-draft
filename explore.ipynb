# %%
import requests

# %%
event_slug = "nba-2027-champion"

event_slug = event_slug.lower().strip()
url = f"https://gamma-api.polymarket.com/events/slug/{event_slug}"
response = requests.get(url)

# %%
response.json()["markets"][0]
# Out:
# {'id': '2243296',
#  'question': 'Will Atlanta Hawks win the 2027 NBA Finals?',
#  'conditionId': '0x6a9ac156f2eee27c3c36e94c88c7384ed4201f58f2c9d1686df3012cfb97f9cc',
#  'slug': 'will-atlanta-hawks-win-the-2027-nba-finals',
#  'endDate': '2027-07-01T00:00:00Z',
#  'liquidity': '200167.85623',
#  'startDate': '2026-05-13T20:07:53.605766Z',
#  'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-2027-champion-cBr9CT4AcdfN.jpg',
#  'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-2027-champion-cBr9CT4AcdfN.jpg',
# ...
